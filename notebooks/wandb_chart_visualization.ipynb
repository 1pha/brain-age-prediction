# %%
import sys
sys.path.append("../")

from sage.config import load_config

# %%
load_config("../config.yml").root
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-9c38ec5f8db7> in <module>
# ----> 1 load_config("../config.yml").root
#
# AttributeError: 'EasyDict' object has no attribute 'root'

# %%
import wandb
api = wandb.Api()

# Project is specified by <entity/project-name>
runs = api.runs("1pha/3d_smri")
summary_list = [] 
config_list = [] 
name_list = [] 
for run in runs: 
    # run.summary are the output key/values like accuracy.
    # We call ._json_dict to omit large files 
    summary_list.append(run.summary._json_dict) 

    # run.config is the input metrics.
    # We remove special values that start with _.
    config = {k:v for k,v in run.config.items() if not k.startswith('_')}
    config_list.append(config) 

    # run.name is the name of the run.
    name_list.append(run.name)       

import pandas as pd 
summary_df = pd.DataFrame.from_records(summary_list) 
config_df = pd.DataFrame.from_records(config_list) 
name_df = pd.DataFrame({'name': name_list}) 
all_df = pd.concat([name_df, config_df,summary_df], axis=1)

# all_df.to_csv("project.csv")

# %%
all_df
# Out:
#                                          name      lr  beta    lamb loss  \
# 0    ResNet (Base) 256 seed98 AUG_REPLACEMENT  0.0001  10.0  0.0005  mse
# 1    ResNet (Base) 256 seed97 AUG_REPLACEMENT  0.0001  10.0  0.0005  mse
# 2    ResNet (Base) 256 seed96 AUG_REPLACEMENT  0.0001  10.0  0.0005  mse
# 3    ResNet (Base) 256 seed95 AUG_REPLACEMENT  0.0001  10.0  0.0005  mse
# 4    ResNet (Base) 256 seed94 AUG_REPLACEMENT  0.0001  10.0  0.0005  mse
# ..                                        ...     ...   ...     ...  ...
# 128          MNI / ALL DB RE-AGE / VRES(PAST)     NaN   NaN  0.0005  mse
# 129   MNI / ALL DB RE-AGE / Resnet No Maxpool     NaN   NaN  0.0005  mse
# 130      MNI / IXI+Dallas / Resnet No Maxpool     NaN   NaN  0.0005  mse
# 131                                     Trial     NaN   NaN  0.0005  mse
# 132                                     Trial     NaN   NaN  0.0005  mse
#
#       plot                                  root  seed  alpha  debug  ...  \
# 0    False  G:/My Drive/brain_data/brainmask_mni  98.0    1.0  False  ...
# 1    False  G:/My Drive/brain_data/brainmask_mni  97.0    1.0  False  ...
# 2    False  G:/My Drive/brain_data/brainmask_mni  96.0    1.0  False  ...
# 3    False  G:/My Drive/brain_data/brainmask_mni  95.0    1.0  False  ...
# 4    False  G:/My Drive/brain_data/brainmask_mni  94.0    1.0  False  ...
# ..     ...                                   ...   ...    ...    ...  ...
# 128    NaN  G:/My Drive/brain_data/brainmask_mni  42.0    NaN  False  ...
# 129    NaN  G:/My Drive/brain_data/brainmask_mni  42.0    NaN  False  ...
# 130    NaN  G:/My Drive/brain_data/brainmask_mni  42.0    NaN  False  ...
# 131    NaN                                   NaN  42.0    NaN  False  ...
# 132    NaN                                   NaN  42.0    NaN  False  ...
#
#          gradients/graph_1feature_extractor.0.bn2.bias  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 128  {'_type': 'histogram', 'bins': [-12.1269187927...
# 129                                                NaN
# 130                                                NaN
# 131                                                NaN
# 132                                                NaN
#
#      gradients/graph_1feature_extractor.1.conv1.weight  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 128  {'_type': 'histogram', 'bins': [-52.1515388488...
# 129                                                NaN
# 130                                                NaN
# 131                                                NaN
# 132                                                NaN
#
#      gradients/graph_1feature_extractor.2.conv2.weight  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 128  {'_type': 'histogram', 'bins': [-28.0632038116...
# 129                                                NaN
# 130                                                NaN
# 131                                                NaN
# 132                                                NaN
#
#          gradients/graph_1feature_extractor.1.bn1.bias  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 128  {'bins': [-6.354912757873535, -6.1951389312744...
# 129                                                NaN
# 130                                                NaN
# 131                                                NaN
# 132                                                NaN
#
#          gradients/graph_1feature_extractor.6.bn1.bias  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 128  {'_type': 'histogram', 'bins': [-0.82329148054...
# 129                                                NaN
# 130                                                NaN
# 131                                                NaN
# 132                                                NaN
#
#          gradients/graph_1feature_extractor.7.bn2.bias  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 128  {'values': [1, 2, 0, 1, 0, 0, 0, 1, 0, 0, 0, 1...
# 129                                                NaN
# 130                                                NaN
# 131                                                NaN
# 132                                                NaN
#
#      gradients/graph_1feature_extractor.4.conv2.weight  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 128  {'bins': [-16.439361572265625, -15.87364673614...
# 129                                                NaN
# 130                                                NaN
# 131                                                NaN
# 132                                                NaN
#
#          gradients/graph_1feature_extractor.5.bn2.bias  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 128  {'bins': [-0.8724374771118164, -0.847808122634...
# 129                                                NaN
# 130                                                NaN
# 131                                                NaN
# 132                                                NaN
#
#      gradients/graph_1feature_extractor.5.conv1.weight  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 128  {'_type': 'histogram', 'values': [2, 1, 0, 0, ...
# 129                                                NaN
# 130                                                NaN
# 131                                                NaN
# 132                                                NaN
#
#      gradients/graph_1feature_extractor.5.conv2.weight
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 128  {'_type': 'histogram', 'bins': [-5.64144563674...
# 129                                                NaN
# 130                                                NaN
# 131                                                NaN
# 132                                                NaN
#
# [133 rows x 697 columns]

# %%
vars(run)
# Out:
# {'_attrs': {'id': 'UnVuOnYxOjJpY3VlNXIyOjNkX3Ntcmk6MXBoYQ==',
#   'tags': [],
#   'name': '2icue5r2',
#   'displayName': 'Trial',
#   'sweepName': None,
#   'state': 'finished',
#   'config': {'lamb': 0.0005,
#    'loss': 'mse',
#    'seed': 42,
#    'debug': False,
#    'double': False,
#    'epochs': 100,
#    'layers': [4, 8, 16, 32],
#    'resize': [96, 96, 96],
#    'augment': False,
#    'dropout': True,
#    'metrics': ['rmse', 'mae', 'r2', 'corr'],
#    'aug_proba': {'flip': 0.33, 'affine': 0.33, 'elastic_deform': 0.33},
#    'batchnorm': True,
#    'run_debug': {'return_all': False},
#    'scheduler': False,
#    'test_size': 0.2,
#    'batch_size': 16,
#    'data_debug': {'rot90': False, 'aug_verbose': False, 'return_path': False},
#    'model_name': 'resnet_no_maxpool',
#    'unused_src': [None],
#    'registration': 'mni',
#    'aug_intensity': {'affine': [0.1, 10], 'elastic_deform': [7, 0.5]},
#    'learning_rate': 0.0001,
#    'mae_threshold': 8,
#    'channel_number': [32, 64, 128, 256, 64],
#    'early_patience': 20,
#    'start_channels': 16,
#    'verbose_period': 5},
#   'group': None,
#   'jobType': None,
#   'commit': '9d193f3ea04cff84758f7b46ca33014494b53e90',
#   'readOnly': False,
#   'createdAt': '2021-05-15T11:05:35',
#   'heartbeatAt': '2021-05-15T11:09:07',
#   'description': 'Trial',
#   'notes': None,
#   'systemMetrics': {'system.cpu': 99.88,
#    'system.disk': 71.3,
#    'system.memory': 60.27,
#    'system.gpu.0.gpu': 76.73,
#    'system.gpu.0.temp': 58.8,
#    'system.gpu.0.memory': 18.67,
#    'system.network.recv': 12931406,
#    'system.network.sent': 3485597,
#    'system.gpu.0.powerWatts': 88.93,
#    'system.proc.cpu.threads': 14.87,
#    'system.gpu.process.0.gpu': 76.73,
#    'system.proc.memory.rssMB': 80.19,
#    'system.gpu.0.powerPercent': 49.41,
#    'system.gpu.process.0.temp': 58.8,
#    'system.proc.memory.percent': 0.49,
#    'system.gpu.process.0.memory': 18.67,
#    'system.gpu.0.memoryAllocated': 54.66,
#    'system.proc.memory.availableMB': 6475.4,
#    'system.gpu.process.0.powerWatts': 88.93,
#    'system.gpu.process.0.powerPercent': 49.41,
#    'system.gpu.process.0.memoryAllocated': 54.66},
#   'summaryMetrics': {'_runtime': 200,
#    'train_r2': -7.609266837828093,
#    'train_mae': 51.76881408691406,
#    'train_corr': 0.3427171229749636,
#    'valid_rmse': 53.6341438293457,
#    '_step': 4,
#    'valid_r2': -7.009455140503599,
#    'valid_mae': 50.24641036987305,
#    '_timestamp': 1621076932,
#    'train_rmse': 54.98533630371094,
#    'valid_corr': 0.37298472037496455},
#   'historyLineCount': 5,
#   'user': {'name': 'Daehyun Cho', 'username': '1pha'},
#   'historyKeys': {'keys': {'system/gpu.0.memoryAllocated': {'typeCounts': [{'type': 'number',
#        'count': 6}],
#      'monotonic': False,
#      'previousValue': -1},
#     'valid_corr': {'typeCounts': [{'type': 'number', 'count': 5}],
#      'monotonic': True,
#      'previousValue': 0.37298472037496455},
#     'train_rmse': {'typeCounts': [{'type': 'number', 'count': 5}],
#      'monotonic': False,
#      'previousValue': 54.98533630371094},
#     'system/gpu.process.0.temp': {'typeCounts': [{'type': 'number',
#        'count': 6}],
#      'monotonic': False,
#      'previousValue': -1},
#     'system/network.recv': {'typeCounts': [{'type': 'number', 'count': 6}],
#      'monotonic': False,
#      'previousValue': -1},
#     'system/gpu.process.0.gpu': {'typeCounts': [{'type': 'number',
#        'count': 6}],
#      'monotonic': False,
#      'previousValue': -1},
#     'system/memory': {'typeCounts': [{'type': 'number', 'count': 6}],
#      'monotonic': False,
#      'previousValue': -1},
#     'valid_r2': {'typeCounts': [{'type': 'number', 'count': 5}],
#      'monotonic': True,
#      'previousValue': -7.009455140503599},
#     'system/gpu.process.0.memoryAllocated': {'typeCounts': [{'type': 'number',
#        'count': 6}],
#      'monotonic': False,
#      'previousValue': -1},
#     'train_corr': {'typeCounts': [{'type': 'number', 'count': 5}],
#      'monotonic': True,
#      'previousValue': 0.3427171229749636},
#     'system/gpu.0.powerPercent': {'typeCounts': [{'type': 'number',
#        'count': 6}],
#      'monotonic': False,
#      'previousValue': -1},
#     'system/gpu.process.0.memory': {'typeCounts': [{'type': 'number',
#        'count': 6}],
#      'monotonic': False,
#      'previousValue': -1},
#     'system/gpu.process.0.powerPercent': {'typeCounts': [{'type': 'number',
#        'count': 6}],
#      'monotonic': False,
#      'previousValue': -1},
#     'train_r2': {'typeCounts': [{'type': 'number', 'count': 5}],
#      'monotonic': True,
#      'previousValue': -7.609266837828093},
#     'system/network.sent': {'typeCounts': [{'type': 'number', 'count': 6}],
#      'monotonic': False,
#      'previousValue': -1},
#     'system/gpu.0.gpu': {'typeCounts': [{'type': 'number', 'count': 6}],
#      'monotonic': False,
#      'previousValue': -1},
#     'system/gpu.0.memory': {'typeCounts': [{'type': 'number', 'count': 6}],
#      'monotonic': False,
#      'previousValue': -1},
#     '_runtime': {'typeCounts': [{'type': 'number', 'count': 5}],
#      'monotonic': True,
#      'previousValue': 200},
#     'system/gpu.process.0.powerWatts': {'typeCounts': [{'type': 'number',
#        'count': 6}],
#      'monotonic': False,
#      'previousValue': -1},
#     'system/disk': {'typeCounts': [{'type': 'number', 'count': 6}],
#      'monotonic': False,
#      'previousValue': -1},
#     'system/cpu': {'typeCounts': [{'type': 'number', 'count': 6}],
#      'monotonic': False,
#      'previousValue': -1},
#     '_step': {'typeCounts': [{'type': 'number', 'count': 5}],
#      'monotonic': True,
#      'previousValue': 4},
#     'system/gpu.0.temp': {'typeCounts': [{'type': 'number', 'count': 6}],
#      'monotonic': False,
#      'previousValue': -1},
#     'system/proc.memory.rssMB': {'typeCounts': [{'type': 'number',
#        'count': 6}],
#      'monotonic': False,
#      'previousValue': -1},
#     '_timestamp': {'typeCounts': [{'type': 'number', 'count': 5}],
#      'monotonic': True,
#      'previousValue': 1621076932.0},
#     'valid_rmse': {'typeCounts': [{'type': 'number', 'count': 5}],
#      'monotonic': False,
#      'previousValue': 53.6341438293457},
#     'system/proc.memory.percent': {'typeCounts': [{'type': 'number',
#        'count': 6}],
#      'monotonic': False,
#      'previousValue': -1},
#     'system/gpu.0.powerWatts': {'typeCounts': [{'type': 'number', 'count': 6}],
#      'monotonic': False,
#      'previousValue': -1},
#     'system/proc.memory.availableMB': {'typeCounts': [{'type': 'number',
#        'count': 6}],
#      'monotonic': False,
#      'previousValue': -1},
#     'system/proc.cpu.threads': {'typeCounts': [{'type': 'number', 'count': 6}],
#      'monotonic': False,
#      'previousValue': -1},
#     'train_mae': {'typeCounts': [{'type': 'number', 'count': 5}],
#      'monotonic': False,
#      'previousValue': 51.76881408691406},
#     'valid_mae': {'typeCounts': [{'type': 'number', 'count': 5}],
#      'monotonic': False,
#      'previousValue': 50.24641036987305}},
#    'lastStep': 4},
#   'rawconfig': {'_wandb': {'t': {'1': [1, 5],
#      '4': '3.8.8',
#      '5': '0.10.30',
#      '8': [1, 2, 3, 5]},
#     'framework': 'torch',
#     'cli_version': '0.10.30',
#     'is_jupyter_run': True,
#     'python_version': '3.8.8',
#     'is_kaggle_kernel': True},
#    'lamb': 0.0005,
#    'loss': 'mse',
#    'seed': 42,
#    'debug': False,
#    'double': False,
#    'epochs': 100,
#    'layers': [4, 8, 16, 32],
#    'resize': [96, 96, 96],
#    'augment': False,
#    'dropout': True,
#    'metrics': ['rmse', 'mae', 'r2', 'corr'],
#    'aug_proba': {'flip': 0.33, 'affine': 0.33, 'elastic_deform': 0.33},
#    'batchnorm': True,
#    'run_debug': {'return_all': False},
#    'scheduler': False,
#    'test_size': 0.2,
#    'batch_size': 16,
#    'data_debug': {'rot90': False, 'aug_verbose': False, 'return_path': False},
#    'model_name': 'resnet_no_maxpool',
#    'unused_src': [None],
#    'registration': 'mni',
#    'aug_intensity': {'affine': [0.1, 10], 'elastic_deform': [7, 0.5]},
#    'learning_rate': 0.0001,
#    'mae_threshold': 8,
#    'channel_number': [32, 64, 128, 256, 64],
#    'early_patience': 20,
#    'start_channels': 16,
#    'verbose_period': 5}},
#  'client': <wandb.apis.public.RetryingClient at 0x2497d333d90>,
#  '_entity': '1pha',
#  'project': '3d_smri',
#  '_files': {},
#  '_base_dir': 'C:\\Users\\pha\\AppData\\Local\\Temp',
#  'sweep': None,
#  'dir': 'C:\\Users\\pha\\AppData\\Local\\Temp\\1pha\\3d_smri\\2icue5r2',
#  '_summary': {'_runtime': 200, 'train_r2': -7.609266837828093, 'train_mae': 51.76881408691406, 'train_corr': 0.3427171229749636, 'valid_rmse': 53.6341438293457, '_step': 4, 'valid_r2': -7.009455140503599, 'valid_mae': 50.24641036987305, '_timestamp': 1621076932, 'train_rmse': 54.98533630371094, 'valid_corr': 0.37298472037496455},
#  'state': 'finished',
#  'user': <wandb.apis.public.User at 0x2497d7b8820>}
